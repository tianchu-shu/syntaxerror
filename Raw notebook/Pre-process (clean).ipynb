# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split, ParameterGrid
from sklearn.metrics import *
import time

# %matplotlib inline

# %%
jailbooking = pd.read_csv("booking.csv")
entries = pd.read_csv("entries_201805311548.csv")
mentalhealth = pd.read_csv('health.csv')
inmate = pd.read_csv('jocojims2inmatedata_201805311745.csv')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (9,10,14,18,19,26,30,31,32,34,35,36,37,38,40,49,52,64,65,66,67) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
inmate.columns
# Out:
# Index(['inmate_no', 'dob', 'age', 'original_sex', 'sex', 'original_race',
#        'race', 'hair', 'eyes', 'height', 'weight', 'mar_stat', 'city', 'state',
#        'zip', 'country', 'birth_place', 'arr_agency', 'original_case_number',
#        'case_no', 'arrest_dt', 'arrest_time', 'trans_agency', 'control_',
#        'bk_dt', 'book_time', 'bonding', 'arr_location', 'b_state', 'mni_no',
#        'location', 'license_state', 'veh_lic__', 'veh_lic_state',
#        'veh_lic_year', 'veh_make', 'veh_model', 'veh_color', 'dna_draw',
#        'l_e_case_', 'same_as_', 'rel_date', 'release_time',
#        'associated_records', 'driver_s_lic_type',
#        'new_booked_inmate___orientation', 'exp_stamp', 'complexion', 'cfn',
#        'demographic_code', 'pros_wksht__', 'ethnic', 'mnh_refer_dt', 'lgbt',
#        'at_risk', 'exploited', 'past_year', 'concerns', 'int_dt',
#        'notify_asap', 'notify_verbal', 'religion', 'diet', 'rstr_liv_cond',
#        'printed_chow', 'prev_bkno', 'ofndr_reg_req', 'ofndr_stamp',
#        'ofndr_match_type', 'ofndr_key', 'gcvalidity', 'gcsrctbl', 'gcscore',
#        'gccity', 'gccounty', 'gcstate', 'gczipcode', 'gctract2010id',
#        'gcblockgroup2010id', 'gcblock2010id', 'hash_ssn', 'hash_ssn4',
#        'hash_lname', 'hash_fname', 'geom', 'dedupe_id'],
#       dtype='object')

# %%
inmate = inmate[['race', 'mar_stat', 'city', 'state', 'zip', 'dedupe_id']]

# %%
inmate = inmate.drop_duplicates(subset=['dedupe_id'])

# %%
inmate.shape
# Out:
# (144254, 6)

# %%
inmate.dedupe_id.nunique()
# Out:
# 144253

# %%
entries.rename(columns={'foreign_id' : 'mni_no'}, inplace=True)
entries = entries[["mni_no", "dedupe_id", 'dob',  'sex']]

# %%
entries.shape
# Out:
# (899470, 4)

# %%
ent_inmate = pd.merge(entries, inmate, left_on='dedupe_id', right_on='dedupe_id')

# %%
ent_inmate.shape
# Out:
# (366077, 9)

# %%
ent_inmate.to_csv("ent_inmate.csv")

# %%
jailbooking.columns
# Out:
# Index(['mni_no', 'case_no', 'case_type', 'booking_no', 'arresting_agency',
#        'arresting_agency_type', 'booking_date', 'release_date', 'bail_type',
#        'bail_amt', 'bailed_out'],
#       dtype='object')

# %%
jailbooking = jailbooking.dropna(subset=['mni_no'])

# %%
jailbooking.shape
# Out:
# (28579, 11)

# %%
ent_inmate[ent_inmate['dedupe_id']==487227]
# Out:
#         mni_no  dedupe_id         dob   sex   race mar_stat         city  \
# 184403  669258   487227.0  1973-02-09  MALE  WHITE        S  KANSAS CITY
# 184404  669263   487227.0  1974-02-09  MALE  WHITE        S  KANSAS CITY
# 184405  141326   487227.0  1974-02-09  MALE  WHITE        S  KANSAS CITY
# 184406  669265   487227.0  1974-02-09  MALE  WHITE        S  KANSAS CITY
# 184407  669261   487227.0  1974-02-09  MALE  WHITE        S  KANSAS CITY
# 184408  669260   487227.0  1974-02-09  MALE  WHITE        S  KANSAS CITY
# 184409  669262   487227.0  1974-02-09  MALE  WHITE        S  KANSAS CITY
# 184410  669264   487227.0  1974-02-09  MALE  WHITE        S  KANSAS CITY
# 184411  669259   487227.0  1974-02-09  MALE  WHITE        S  KANSAS CITY
#
#        state    zip
# 184403    KS  66103
# 184404    KS  66103
# 184405    KS  66103
# 184406    KS  66103
# 184407    KS  66103
# 184408    KS  66103
# 184409    KS  66103
# 184410    KS  66103
# 184411    KS  66103

# %%
withbooking = pd.merge(ent_inmate, jailbooking, on='mni_no')

# %%
withbooking[withbooking['dedupe_id']==309]
# Out:
#        mni_no  dedupe_id         dob   sex   race mar_stat    city state  \
# 11129  673675      309.0  1978-04-07  MALE  WHITE        S  OLATHE    KS
# 11130  673675      309.0  1978-04-07  MALE  WHITE        S  OLATHE    KS
# 11131  673675      309.0  1978-04-07  MALE  WHITE        S  OLATHE    KS
#
#          zip    case_no case_type  booking_no arresting_agency  \
# 11129  66061  14DV00270        DV    14002590      OLATHE P.D.
# 11130  66061  15DV00382        DV    15003546      LENEXA P.D.
# 11131  66061  16DV00234        DV    16002371      LENEXA P.D.
#
#       arresting_agency_type         booking_date         release_date  \
# 11129                  CITY  2014-03-04 00:00:00  2014-03-05 00:00:00
# 11130                  CITY  2015-03-26 00:00:00  2015-03-27 00:00:00
# 11131                  CITY  2016-02-24 00:00:00  2016-04-28 00:00:00
#
#       bail_type  bail_amt  bailed_out
# 11129        PR    1500.0        True
# 11130       SUR    1000.0        True
# 11131       NaN       NaN       False

# %%
mentalhealth.columns
# Out:
# Index(['hash_ssn', 'hash_ssn4', 'hash_lname', 'hash_fname', 'patid', 'dob',
#        'race', 'sex', 'hash_gcstreetaddress', 'city', 'state', 'zip',
#        'gcvalidity', 'gcsrctabl', 'gcscore', 'gccity', 'gccounty', 'gcstate',
#        'gczipcode', 'hash_gclonglat', 'gctract2010id', 'gcblockgroup2010id',
#        'gcblock2010id', 'admit_date', 'dschrg_date', 'program', 'pri_dx_code',
#        'pri_dx_value', 'refferal_source', 'case_id', 'dedupe_id'],
#       dtype='object')

# %%
mentalhealth = mentalhealth[['dedupe_id','pri_dx_value', 'refferal_source']]

# %%
mentalhealth.head()
# Out:
#    dedupe_id                                       pri_dx_value  \
# 0   190642.0                    UNSPECIFIED AFFECTIVE PSYCHOSIS
# 1     1780.0                            DEPRESSIVE DISORDER NOS
# 2   583264.0  BIPOLAR DISORDER, DEPRESSED, SEVERE W/O PSYCHO...
# 3   666871.0  SCHIZOPHRENIC DISORDER, SCHIZO-AFFECTIVE TYPE,...
# 4   114636.0  MANIC DISORDER, SINGLE EPISODE, IN FULL REMISSION
#
#   refferal_source
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4            SELF

# %%
mentalhealth['refferal_source'].loc[mentalhealth['refferal_source'] != 'SELF'] = 'OTHERS'

# %%
mentalhealth.head()
# Out:
#    dedupe_id                                       pri_dx_value  \
# 0   190642.0                    UNSPECIFIED AFFECTIVE PSYCHOSIS
# 1     1780.0                            DEPRESSIVE DISORDER NOS
# 2   583264.0  BIPOLAR DISORDER, DEPRESSED, SEVERE W/O PSYCHO...
# 3   666871.0  SCHIZOPHRENIC DISORDER, SCHIZO-AFFECTIVE TYPE,...
# 4   114636.0  MANIC DISORDER, SINGLE EPISODE, IN FULL REMISSION
#
#   refferal_source
# 0          OTHERS
# 1          OTHERS
# 2          OTHERS
# 3          OTHERS
# 4            SELF

# %%
mentalhealth['pri_dx_value'].fillna('missing', inplace = True)

# %%
mentalhealth['refferal_source'].fillna('OTHERS', inplace = True)

# %%
mentalhealth.drop_duplicates(subset=['dedupe_id'])
# Out:
#        dedupe_id                                       pri_dx_value  \
# 0       190642.0                    UNSPECIFIED AFFECTIVE PSYCHOSIS
# 1         1780.0                            DEPRESSIVE DISORDER NOS
# 2       583264.0  BIPOLAR DISORDER, DEPRESSED, SEVERE W/O PSYCHO...
# 3       666871.0  SCHIZOPHRENIC DISORDER, SCHIZO-AFFECTIVE TYPE,...
# 4       114636.0  MANIC DISORDER, SINGLE EPISODE, IN FULL REMISSION
# 5        38306.0                                     PANIC DISORDER
# 6       197461.0     MAJOR DEPRESSIVE DISORDER, RECURRENT, MODERATE
# 7        74789.0      ATTENTION DEFICIT DISORDER WITH HYPERACTIVITY
# 8       439589.0           PROLONGED POST TRAUMATIC STRESS DISORDER
# 9       716225.0              SCHIZOPHRENIC DISORDER, PARANOID TYPE
# 10      619848.0                      BIPOLAR DISORDER, UNSPECIFIED
# 11      370526.0         MAJOR DEPRESSIVE DISORDER, RECURRENT, MILD
# 12      132831.0  MAJOR DEPRESS. DISORDER, RECURRENT, W/ PSYCH F...
# 13      521749.0              ADJUSTMENT REACTION WITH ANXIOUS MOOD
# 14      597341.0                    UNSPECIFIED AFFECTIVE PSYCHOSIS
# 15      167361.0                    UNSPECIFIED AFFECTIVE PSYCHOSIS
# 16      331950.0                            DEPRESSIVE DISORDER NOS
# 17      666055.0        POST-TRAUMATIC STRESS DISORDER, UNSPECIFIED
# 18      531376.0  MAJOR DEPRESSIVE DISORDER, RECURRENT, UNSPECIFIED
# 19      589464.0            MANIC DEPRESSIVE PSYCHOSIS, UNSPECIFIED
# 20      187747.0                         ANXIETY STATE, UNSPECIFIED
# 21      426683.0  MAJOR DEPRESSIVE DISORDER, RECURRENT, SEVERE W...
# 22      554619.0                                            missing
# 23      111693.0                            DEPRESSIVE DISORDER NOS
# 24      108571.0                                            missing
# 25      630050.0  OTHER SPECIFIED EARLY CHILDHOOD PSYCHOSES, CUR...
# 26      677574.0                                            missing
# 27      303951.0         MAJOR DEPRESSIVE DISORDER, RECURRENT, MILD
# 28      666019.0            MANIC DEPRESSIVE PSYCHOSIS, UNSPECIFIED
# 29       23345.0                            DEPRESSIVE DISORDER NOS
# ...          ...                                                ...
# 26050   745862.0                    UNSPECIFIED AFFECTIVE PSYCHOSIS
# 26052   746198.0  MAJOR DEPRESSIVE DISORDER, SINGLE EPISODE, MOD...
# 26055   746283.0  ADJUSTMENT DISORDER WITH MIXED EMOTIONAL FEATURES
# 26056   746410.0                            DEPRESSIVE DISORDER NOS
# 26057   746638.0            ADJUSTMENT DISORDER WITH DEPRESSED MOOD
# 26058   747575.0                       GENERALIZED ANXIETY DISORDER
# 26060   747610.0  ATTN-DEFCT HYPERACTIVITY DISORDER, PREDOM INAT...
# 26062   747640.0                CONDUCT DISORDER, UNSPECIFIED ONSET
# 26064   748161.0      ATTENTION DEFICIT DISORDER WITH HYPERACTIVITY
# 26067   748944.0                       GENERALIZED ANXIETY DISORDER
# 26068   748950.0                    UNSPECIFIED AFFECTIVE PSYCHOSIS
# 26069   749311.0                      IMPULSE DISORDER, UNSPECIFIED
# 26070   749584.0  ATTN-DEFCT HYPERACTIVITY DISORDER, PREDOM INAT...
# 26071   749688.0                              UNSPECIFIED PSYCHOSIS
# 26072   749987.0                       GENERALIZED ANXIETY DISORDER
# 26074   750187.0      ATTENTION DEFICIT DISORDER WITH HYPERACTIVITY
# 26075   750267.0              UNSPECIFIED MOOD [AFFECTIVE] DISORDER
# 26078   750470.0            MANIC DEPRESSIVE PSYCHOSIS, UNSPECIFIED
# 26079   750622.0                            DEPRESSIVE DISORDER NOS
# 26080   750891.0                               OTHER MANIC EPISODES
# 26082   751110.0            MANIC DEPRESSIVE PSYCHOSIS, UNSPECIFIED
# 26084   751320.0      ATTENTION DEFICIT DISORDER WITH HYPERACTIVITY
# 26085   751414.0              ADJUSTMENT REACTION WITH ANXIOUS MOOD
# 26086   751428.0                            DEPRESSIVE DISORDER NOS
# 26088   751669.0        OTHER PERSISTENT MOOD [AFFECTIVE] DISORDERS
# 26089   751896.0                 UNSPECIFIED DISTURBANCE OF CONDUCT
# 26090   752020.0                    INTERMITTENT EXPLOSIVE DISORDER
# 26091   752160.0  ADJUSTMENT DISORDER W/MIXED DISTURBANCE OF EMO...
# 26092   752173.0        MAJ DEPRESS. DIS. SNGL EPIS. SEV. W/O PSYCH
# 26095   752567.0                    UNSPECIFIED AFFECTIVE PSYCHOSIS
#
#       refferal_source
# 0              OTHERS
# 1              OTHERS
# 2              OTHERS
# 3              OTHERS
# 4                SELF
# 5              OTHERS
# 6              OTHERS
# 7              OTHERS
# 8              OTHERS
# 9              OTHERS
# 10             OTHERS
# 11               SELF
# 12             OTHERS
# 13             OTHERS
# 14             OTHERS
# 15               SELF
# 16               SELF
# 17             OTHERS
# 18               SELF
# 19               SELF
# 20             OTHERS
# 21             OTHERS
# 22             OTHERS
# 23             OTHERS
# 24             OTHERS
# 25             OTHERS
# 26             OTHERS
# 27               SELF
# 28             OTHERS
# 29             OTHERS
# ...               ...
# 26050          OTHERS
# 26052          OTHERS
# 26055          OTHERS
# 26056          OTHERS
# 26057          OTHERS
# 26058          OTHERS
# 26060          OTHERS
# 26062          OTHERS
# 26064          OTHERS
# 26067            SELF
# 26068          OTHERS
# 26069          OTHERS
# 26070          OTHERS
# 26071          OTHERS
# 26072          OTHERS
# 26074          OTHERS
# 26075          OTHERS
# 26078            SELF
# 26079          OTHERS
# 26080          OTHERS
# 26082          OTHERS
# 26084          OTHERS
# 26085          OTHERS
# 26086          OTHERS
# 26088          OTHERS
# 26089          OTHERS
# 26090          OTHERS
# 26091          OTHERS
# 26092            SELF
# 26095            SELF
#
# [21244 rows x 3 columns]

# %%
almost_done = pd.merge(withbooking, mentalhealth, on='dedupe_id', how='left')

# %%
almost_done.shape
# Out:
# (34823, 21)

# %%
withbooking=withbooking.drop_duplicates()

# %%
withbooking[withbooking['mni_no']==658145]
# Out:
#    mni_no  dedupe_id         dob     sex   race mar_stat      city state  \
# 3  658145   350849.0  1997-04-12  FEMALE  WHITE        S  EDGERTON    KS
#
#      zip    case_no case_type  booking_no  \
# 3  66021  15CR02335        CR    15011570
#
#                       arresting_agency arresting_agency_type  \
# 3  JOHNSON COUNTY SHERIFF'S DEPARTMENT        COUNTY SHERIFF
#
#           booking_date         release_date bail_type  bail_amt  bailed_out
# 3  2015-10-07 00:00:00  2015-10-07 00:00:00       SUR   10000.0        True

# %%
withbooking.dedupe_id.nunique()
# Out:
# 21258

# %%
withbooking.shape
# Out:
# (27904, 19)

# %%
withbooking.mni_no.nunique()
# Out:
# 21130

# %%
almost_done
# Out:
#        mni_no  dedupe_id         dob     sex                       race  \
# 0      679537   301831.0  1974-04-02    MALE                      WHITE
# 1      431835   296410.0  1971-01-01    MALE                      WHITE
# 2      431835   296410.0  1971-01-01    MALE                      WHITE
# 3      658145   350849.0  1997-04-12  FEMALE                      WHITE
# 4      658145   350849.0  1997-04-12  FEMALE                      WHITE
# 5      655865   370683.0  1984-08-03    MALE                      WHITE
# 6      631990   467807.0  1975-02-18    MALE                      WHITE
# 7      510773   103594.0  1991-06-11    MALE                      WHITE
# 8      694772   112221.0  1952-02-01    MALE                      WHITE
# 9      694772   112221.0  1952-02-01    MALE                      WHITE
# 10     704863   221941.0  1990-04-30    MALE                      WHITE
# 11      58336   227037.0  1959-10-28    MALE                      WHITE
# 12     587326   230580.0  1990-12-19  FEMALE                      WHITE
# 13     587326   230580.0  1990-12-19  FEMALE                      WHITE
# 14     494538   257633.0  1987-01-26    MALE                      WHITE
# 15     494538   257633.0  1987-01-26    MALE                      WHITE
# 16     539014   542695.0  1991-04-12    MALE                      WHITE
# 17     539014   542695.0  1991-04-12    MALE                      WHITE
# 18      67267   109603.0  1974-01-11  FEMALE                      WHITE
# 19      67267   661191.0  1965-09-07    MALE                      WHITE
# 20     621169    25520.0  1973-04-21  FEMALE                      WHITE
# 21     514367   415592.0  1987-09-26    MALE  BLACK OR AFRICAN AMERICAN
# 22     139761    28340.0  1980-07-07  FEMALE                      WHITE
# 23     139761    28340.0  1980-07-07  FEMALE                      WHITE
# 24     139761    28340.0  1980-07-07  FEMALE                      WHITE
# 25     548064   407156.0  1992-04-08    MALE                      WHITE
# 26     548064   407156.0  1992-04-08    MALE                      WHITE
# 27     548064   407156.0  1992-04-08    MALE                      WHITE
# 28     548064   407156.0  1992-04-08    MALE                      WHITE
# 29     548064   407156.0  1992-04-08    MALE                      WHITE
# ...       ...        ...         ...     ...                        ...
# 34793  637080   439886.0  1990-02-19    MALE  BLACK OR AFRICAN AMERICAN
# 34794  668119   533711.0  1956-01-09    MALE                      WHITE
# 34795  617003   556426.0  1985-07-03    MALE                      WHITE
# 34796  632418   648270.0  1964-10-22    MALE                      WHITE
# 34797  665935   450785.0  1980-11-05    MALE                      WHITE
# 34798  610752   677498.0  1990-12-07    MALE  BLACK OR AFRICAN AMERICAN
# 34799   52793   744973.0  1961-08-05    MALE                      WHITE
# 34800  691375   388168.0  1974-04-23    MALE                      WHITE
# 34801  686722   592745.0  1980-06-26    MALE                      WHITE
# 34802  621172   343542.0  1973-04-04    MALE  BLACK OR AFRICAN AMERICAN
# 34803  621172   343542.0  1973-04-04    MALE  BLACK OR AFRICAN AMERICAN
# 34804  487392   135513.0  1988-04-23    MALE                      WHITE
# 34805  141481   579950.0  1979-11-03    MALE                      WHITE
# 34806  526087   223013.0  1992-06-02  FEMALE  BLACK OR AFRICAN AMERICAN
# 34807  526087   223013.0  1992-06-02  FEMALE  BLACK OR AFRICAN AMERICAN
# 34808  526087   223013.0  1992-06-02  FEMALE  BLACK OR AFRICAN AMERICAN
# 34809  526087   223013.0  1992-06-02  FEMALE  BLACK OR AFRICAN AMERICAN
# 34810  661283   236650.0  1977-04-11  FEMALE                      WHITE
# 34811  595509   413161.0  1981-12-31    MALE                      WHITE
# 34812  643099   665393.0  1993-11-01    MALE  BLACK OR AFRICAN AMERICAN
# 34813  703461    20065.0  1982-03-11  FEMALE                      WHITE
# 34814  691211    91326.0  1992-10-29    MALE                      WHITE
# 34815  649115   742493.0  1995-11-26    MALE                      WHITE
# 34816  624233   544732.0  1981-05-10    MALE                      WHITE
# 34817  393726   674256.0  1984-03-07    MALE                      WHITE
# 34818  393726   674256.0  1984-03-07    MALE                      WHITE
# 34819  697108    35713.0  1988-05-11  FEMALE                      WHITE
# 34820  354499   359078.0  1986-06-19    MALE                      WHITE
# 34821  354499   359078.0  1986-06-19    MALE                      WHITE
# 34822  606679   550016.0  1981-02-04    MALE                      WHITE
#
#       mar_stat            city state    zip    case_no       ...        \
# 0            M         SHAWNEE    KS  66226  15CR00773       ...
# 1          NaN          OLATHE    KS  66062  13CR00129       ...
# 2          NaN          OLATHE    KS  66062  14CR00932       ...
# 3            S        EDGERTON    KS  66021  15CR02335       ...
# 4            S        EDGERTON    KS  66021  15CR02335       ...
# 5            S          OLATHE    KS  66062  13CR00468       ...
# 6            M         LEAWOOD    KS  66209  11DV01549       ...
# 7            S   OVERLAND PARK    KS  66212  15DV00580       ...
# 8            M   OVERLAND PARK    KS  66210  15CR01391       ...
# 9            M   OVERLAND PARK    KS  66210  15CR02428       ...
# 10           S     KANSAS CITY    MO  64155  16CR00429       ...
# 11           M         SHAWNEE    KS  66203  12DV01408       ...
# 12         NaN          OLATHE    KS  66061  10CR00595       ...
# 13         NaN          OLATHE    KS  66061  12DV00006       ...
# 14           S          LENEXA    KS  66227  11CR01188       ...
# 15           S          LENEXA    KS  66227  15CR00414       ...
# 16           S         SHAWNEE    KS  66216  14CR02341       ...
# 17           S         SHAWNEE    KS  66216  14CR02341       ...
# 18           S         SHAWNEE    KS  66203  10CR00866       ...
# 19           S          OLATHE    KS  66062  10CR00866       ...
# 20           D         GARDNER    KS  66030  11DV00523       ...
# 21           S     KANSAS CITY    KS  66102  14DV00162       ...
# 22         NaN     KANSAS CITY    KS  66106  11DV00212       ...
# 23         NaN     KANSAS CITY    KS  66106  12DV00734       ...
# 24         NaN     KANSAS CITY    KS  66106  14DV00024       ...
# 25           S   OVERLAND PARK    KS  66204  11DV00831       ...
# 26           S   OVERLAND PARK    KS  66204  13CR02804       ...
# 27           S   OVERLAND PARK    KS  66204  13DV00715       ...
# 28           S   OVERLAND PARK    KS  66204  11DV00831       ...
# 29           S   OVERLAND PARK    KS  66204  13CR02804       ...
# ...        ...             ...   ...    ...        ...       ...
# 34793        S     KANSAS CITY    MO  64110  12CR00470       ...
# 34794        S          OLATHE    KS  66061  13CR02491       ...
# 34795        M          OLATHE    KS  66061  11DV00179       ...
# 34796        M    EDWARDSVILLE    KS  66113  12CR00431       ...
# 34797        S   OVERLAND PARK    KS  66210  16DV00055       ...
# 34798        S     KANSAS CITY    MO  64108  10CR02484       ...
# 34799        M          OLATHE    KS  66062  16DV00119       ...
# 34800        M   OVERLAND PARK    KS  66210  15DV00415       ...
# 34801        S     KANSAS CITY    MO  64113  14DV01514       ...
# 34802        S   OVERLAND PARK    KS  66212  11DV00532       ...
# 34803        S   OVERLAND PARK    KS  66212  16CR00856       ...
# 34804        S     KANSAS CITY    KS  66103  14CR02025       ...
# 34805        S        STILWELL    KS  66085  14CR00357       ...
# 34806        S     KANSAS CITY    MO  64130  07JV00027       ...
# 34807        S     KANSAS CITY    MO  64130  11CR00649       ...
# 34808        S     KANSAS CITY    MO  64130  07JV00027       ...
# 34809        S     KANSAS CITY    MO  64130  11CR00649       ...
# 34810        S     SPRING HILL    KS  66083  13DV01566       ...
# 34811      NaN   OVERLAND PARK    KS  66212  10CR00246       ...
# 34812        S   OVERLAND PARK    KS  66213  13CR00146       ...
# 34813        S  JEFFERSON CITY    MO  65101  16CR00095       ...
# 34814        S     KANSAS CITY    KS  66102  15DV00400       ...
# 34815        S   OVERLAND PARK    KS  66207  15DV00451       ...
# 34816      NaN          LENEXA    KS  66215  15CR02999       ...
# 34817        S   OVERLAND PARK    KS  66212  10CR01234       ...
# 34818        S   OVERLAND PARK    KS  66212  10CR01234       ...
# 34819        M          GIDEON    MO  63848  15DV00978       ...
# 34820        S     KANSAS CITY    MO  64137  14DV01165       ...
# 34821        S     KANSAS CITY    MO  64137  14DV01165       ...
# 34822        D      CLARKRANGE    TN  38553  10CR01863       ...
#
#       booking_no                     arresting_agency arresting_agency_type  \
# 0       15003768  JOHNSON COUNTY SHERIFF'S DEPARTMENT        COUNTY SHERIFF
# 1       13000836  JOHNSON COUNTY SHERIFF'S DEPARTMENT        COUNTY SHERIFF
# 2       14005131  JOHNSON COUNTY SHERIFF'S DEPARTMENT        COUNTY SHERIFF
# 3       15011570  JOHNSON COUNTY SHERIFF'S DEPARTMENT        COUNTY SHERIFF
# 4       15011570  JOHNSON COUNTY SHERIFF'S DEPARTMENT        COUNTY SHERIFF
# 5       13002475  JOHNSON COUNTY SHERIFF'S DEPARTMENT        COUNTY SHERIFF
# 6       11014542  JOHNSON COUNTY SHERIFF'S DEPARTMENT        COUNTY SHERIFF
# 7       15005330                   OVERLAND PARK P.D.                  CITY
# 8       15006763                 PRAIRIE VILLAGE P.D.                  CITY
# 9       15011602                   OVERLAND PARK P.D.                  CITY
# 10      16001911                KANSAS HIGHWAY PATROL                 STATE
# 11      12012426                         SHAWNEE P.D.                  CITY
# 12      10003486  JOHNSON COUNTY SHERIFF'S DEPARTMENT        COUNTY SHERIFF
# 13      12000013                   OVERLAND PARK P.D.                  CITY
# 14      11006356                         SHAWNEE P.D.                  CITY
# 15      15002918  JOHNSON COUNTY SHERIFF'S DEPARTMENT        COUNTY SHERIFF
# 16      14012292  JOHNSON COUNTY SHERIFF'S DEPARTMENT        COUNTY SHERIFF
# 17      14012292  JOHNSON COUNTY SHERIFF'S DEPARTMENT        COUNTY SHERIFF
# 18      10004550                          OLATHE P.D.                  CITY
# 19      10004550                          OLATHE P.D.                  CITY
# 20      11005170                         GARDNER P.D.                  CITY
# 21      14001488                   OVERLAND PARK P.D.                  CITY
# 22      11002143                          OLATHE P.D.                  CITY
# 23      12006484                          OLATHE P.D.                  CITY
# 24      14000206                          OLATHE P.D.                  CITY
# 25      11007979                   OVERLAND PARK P.D.                  CITY
# 26      13014132  JOHNSON COUNTY SHERIFF'S DEPARTMENT        COUNTY SHERIFF
# 27      13006876                          OLATHE P.D.                  CITY
# 28      11007979                   OVERLAND PARK P.D.                  CITY
# 29      13014132  JOHNSON COUNTY SHERIFF'S DEPARTMENT        COUNTY SHERIFF
# ...          ...                                  ...                   ...
# 34793   12003011  JOHNSON COUNTY SHERIFF'S DEPARTMENT        COUNTY SHERIFF
# 34794   13012497  JOHNSON COUNTY SHERIFF'S DEPARTMENT        COUNTY SHERIFF
# 34795   11001779                          OLATHE P.D.                  CITY
# 34796   14000132  JOHNSON COUNTY SHERIFF'S DEPARTMENT        COUNTY SHERIFF
# 34797   16000489                   OVERLAND PARK P.D.                  CITY
# 34798   10013109                   OVERLAND PARK P.D.                  CITY
# 34799   16001155                          OLATHE P.D.                  CITY
# 34800   15003845                   OVERLAND PARK P.D.                  CITY
# 34801   14014207  JOHNSON COUNTY SHERIFF'S DEPARTMENT        COUNTY SHERIFF
# 34802   11005180                   OVERLAND PARK P.D.                  CITY
# 34803   16003765                KANSAS HIGHWAY PATROL                 STATE
# 34804   14011457  JOHNSON COUNTY SHERIFF'S DEPARTMENT        COUNTY SHERIFF
# 34805   14001866  JOHNSON COUNTY SHERIFF'S DEPARTMENT        COUNTY SHERIFF
# 34806   10000223  JOHNSON COUNTY SHERIFF'S DEPARTMENT        COUNTY SHERIFF
# 34807   11003734                          OLATHE P.D.                  CITY
# 34808   10000223  JOHNSON COUNTY SHERIFF'S DEPARTMENT        COUNTY SHERIFF
# 34809   11003734                          OLATHE P.D.                  CITY
# 34810   13014614  JOHNSON COUNTY SHERIFF'S DEPARTMENT        COUNTY SHERIFF
# 34811   10001297                   OVERLAND PARK P.D.                  CITY
# 34812   13001028  JOHNSON COUNTY SHERIFF'S DEPARTMENT        COUNTY SHERIFF
# 34813   16000450  JOHNSON COUNTY SHERIFF'S DEPARTMENT        COUNTY SHERIFF
# 34814   15003714                         MERRIAM P.D.                  CITY
# 34815   15004245                          OLATHE P.D.                  CITY
# 34816   15014095                         MERRIAM P.D.                  CITY
# 34817   10006739  JOHNSON COUNTY SHERIFF'S DEPARTMENT        COUNTY SHERIFF
# 34818   10006739  JOHNSON COUNTY SHERIFF'S DEPARTMENT        COUNTY SHERIFF
# 34819   15008865                   OVERLAND PARK P.D.                  CITY
# 34820   14011116                   OVERLAND PARK P.D.                  CITY
# 34821   14011116                   OVERLAND PARK P.D.                  CITY
# 34822   10009716                   OVERLAND PARK P.D.                  CITY
#
#               booking_date         release_date bail_type bail_amt  \
# 0      2015-04-01 00:00:00  2015-04-01 00:00:00        CA  10000.0
# 1      2013-01-19 00:00:00  2013-01-22 00:00:00       SUR  10000.0
# 2      2014-05-02 00:00:00  2014-05-02 00:00:00       SUR   5000.0
# 3      2015-10-07 00:00:00  2015-10-07 00:00:00       SUR  10000.0
# 4      2015-10-07 00:00:00  2015-10-07 00:00:00       SUR  10000.0
# 5      2013-03-03 00:00:00  2013-03-03 00:00:00       SUR   1000.0
# 6      2011-12-01 00:00:00  2011-12-01 00:00:00       SUR   3500.0
# 7      2015-05-07 00:00:00  2015-05-08 00:00:00        PR   2500.0
# 8      2015-06-11 00:00:00  2015-06-12 00:00:00       SUR   5000.0
# 9      2015-10-08 00:00:00  2015-10-08 00:00:00       SUR  25000.0
# 10     2016-02-14 00:00:00  2016-02-14 00:00:00       SUR   2500.0
# 11     2012-10-16 00:00:00  2012-10-16 00:00:00        PR   1000.0
# 12     2010-03-16 00:00:00  2010-03-17 00:00:00       SUR   1500.0
# 13     2012-01-01 00:00:00  2012-01-02 00:00:00      ORCD   1000.0
# 14     2011-05-26 00:00:00  2011-05-27 00:00:00       SUR   5000.0
# 15     2015-03-10 00:00:00  2015-03-10 00:00:00       SUR   5000.0
# 16     2014-10-21 00:00:00  2014-12-16 00:00:00        PR   1000.0
# 17     2014-10-21 00:00:00  2014-12-16 00:00:00        PR   1000.0
# 18     2010-04-08 00:00:00  2010-04-08 00:00:00       SUR  10000.0
# 19     2010-04-08 00:00:00  2010-04-08 00:00:00       SUR  10000.0
# 20     2011-05-02 00:00:00  2011-05-02 00:00:00        PR   1500.0
# 21     2014-02-06 00:00:00  2014-02-06 00:00:00       SUR    500.0
# 22     2011-02-21 00:00:00  2011-02-21 00:00:00       SUR   1500.0
# 23     2012-05-31 00:00:00  2012-07-17 00:00:00        PR   5000.0
# 24     2014-01-07 00:00:00  2014-05-07 00:00:00       NaN      NaN
# 25     2011-07-01 00:00:00  2011-07-02 00:00:00        PR    750.0
# 26     2013-12-06 00:00:00  2013-12-06 00:00:00       SUR  10000.0
# 27     2013-06-15 00:00:00  2013-06-16 00:00:00       SUR   2500.0
# 28     2011-07-01 00:00:00  2011-07-02 00:00:00        PR    750.0
# 29     2013-12-06 00:00:00  2013-12-06 00:00:00       SUR  10000.0
# ...                    ...                  ...       ...      ...
# 34793  2012-03-09 00:00:00  2013-06-25 00:00:00       NaN      NaN
# 34794  2013-10-27 00:00:00  2013-10-27 00:00:00        CA   1000.0
# 34795  2011-02-12 00:00:00  2011-05-31 00:00:00       NaN      NaN
# 34796  2014-01-04 00:00:00  2014-01-04 00:00:00       SUR   2500.0
# 34797  2016-01-13 00:00:00  2016-01-13 00:00:00       SUR   1500.0
# 34798  2010-10-10 00:00:00  2010-10-11 00:00:00       SUR   2000.0
# 34799  2016-01-27 00:00:00  2016-01-28 00:00:00        PR   2500.0
# 34800  2015-04-03 00:00:00  2015-04-03 00:00:00       SUR   1500.0
# 34801  2014-12-10 00:00:00  2014-12-10 00:00:00       SUR   1500.0
# 34802  2011-05-02 00:00:00  2011-05-04 00:00:00       SUR   2500.0
# 34803  2016-03-27 00:00:00  2016-03-28 00:00:00        PR   2500.0
# 34804  2014-09-29 00:00:00  2014-10-01 00:00:00       SUR  10000.0
# 34805  2014-02-15 00:00:00  2014-02-15 00:00:00       GPS   1000.0
# 34806  2010-02-03 00:00:00  2010-02-04 00:00:00       NaN      NaN
# 34807  2011-03-29 00:00:00  2011-03-29 00:00:00       SUR   2500.0
# 34808  2010-02-03 00:00:00  2010-02-04 00:00:00       NaN      NaN
# 34809  2011-03-29 00:00:00  2011-03-29 00:00:00       SUR   2500.0
# 34810  2013-12-18 00:00:00  2013-12-18 00:00:00       SUR   2500.0
# 34811  2010-01-29 00:00:00  2010-01-30 00:00:00       SUR   1500.0
# 34812  2013-01-24 00:00:00  2013-04-01 00:00:00        PR  10000.0
# 34813  2016-01-12 00:00:00  2016-01-12 00:00:00       SUR   1000.0
# 34814  2015-03-30 00:00:00  2015-03-31 00:00:00        PR   1000.0
# 34815  2015-04-13 00:00:00  2015-04-13 00:00:00        PR   2500.0
# 34816  2015-12-09 00:00:00  2015-12-09 00:00:00       SUR   5000.0
# 34817  2010-05-26 00:00:00  2010-05-27 00:00:00       SUR  10000.0
# 34818  2010-05-26 00:00:00  2010-05-27 00:00:00       SUR  10000.0
# 34819  2015-08-02 00:00:00  2015-08-03 00:00:00        PR   2500.0
# 34820  2014-09-20 00:00:00  2014-09-20 00:00:00       SUR      0.0
# 34821  2014-09-20 00:00:00  2014-09-20 00:00:00       SUR      0.0
# 34822  2010-07-30 00:00:00  2011-01-25 00:00:00       NaN      NaN
#
#        bailed_out                                       pri_dx_value  \
# 0            True  MAJOR DEPRESSIVE DISORDER, SINGLE EPISODE, MOD...
# 1            True                                      SOCIAL PHOBIA
# 2            True                                      SOCIAL PHOBIA
# 3            True                                                NaN
# 4            True                                                NaN
# 5            True                                                NaN
# 6            True                                                NaN
# 7            True                                                NaN
# 8            True                                                NaN
# 9            True                                                NaN
# 10           True                                                NaN
# 11           True                                                NaN
# 12           True          MANIC DEPRESSIVE PSYCHOSIS, OTHER (MIXED)
# 13           True          MANIC DEPRESSIVE PSYCHOSIS, OTHER (MIXED)
# 14           True                                                NaN
# 15           True                                                NaN
# 16           True                                                NaN
# 17           True                                                NaN
# 18           True              BIPOLAR DISORDER, DEPRESSED, MODERATE
# 19           True                                                NaN
# 20           True                                                NaN
# 21           True                                                NaN
# 22           True           PROLONGED POST TRAUMATIC STRESS DISORDER
# 23           True           PROLONGED POST TRAUMATIC STRESS DISORDER
# 24          False           PROLONGED POST TRAUMATIC STRESS DISORDER
# 25           True                                                NaN
# 26           True                                                NaN
# 27           True                                                NaN
# 28           True                                                NaN
# 29           True                                                NaN
# ...           ...                                                ...
# 34793       False                                                NaN
# 34794        True                                                NaN
# 34795       False                                                NaN
# 34796        True                                                NaN
# 34797        True                                                NaN
# 34798        True                                                NaN
# 34799        True                                                NaN
# 34800        True                                                NaN
# 34801        True                                                NaN
# 34802        True                                                NaN
# 34803        True                                                NaN
# 34804        True                                                NaN
# 34805        True                                                NaN
# 34806       False                                                NaN
# 34807        True                                                NaN
# 34808       False                                                NaN
# 34809        True                                                NaN
# 34810        True                                                NaN
# 34811        True                                                NaN
# 34812        True                                                NaN
# 34813        True                                                NaN
# 34814        True                                                NaN
# 34815        True                                                NaN
# 34816        True                                                NaN
# 34817        True                                                NaN
# 34818        True                                                NaN
# 34819        True                                                NaN
# 34820        True                                                NaN
# 34821        True                                                NaN
# 34822       False                                                NaN
#
#       refferal_source
# 0              OTHERS
# 1              OTHERS
# 2              OTHERS
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12               SELF
# 13               SELF
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18             OTHERS
# 19                NaN
# 20                NaN
# 21                NaN
# 22               SELF
# 23               SELF
# 24               SELF
# 25                NaN
# 26                NaN
# 27                NaN
# 28                NaN
# 29                NaN
# ...               ...
# 34793             NaN
# 34794             NaN
# 34795             NaN
# 34796             NaN
# 34797             NaN
# 34798             NaN
# 34799             NaN
# 34800             NaN
# 34801             NaN
# 34802             NaN
# 34803             NaN
# 34804             NaN
# 34805             NaN
# 34806             NaN
# 34807             NaN
# 34808             NaN
# 34809             NaN
# 34810             NaN
# 34811             NaN
# 34812             NaN
# 34813             NaN
# 34814             NaN
# 34815             NaN
# 34816             NaN
# 34817             NaN
# 34818             NaN
# 34819             NaN
# 34820             NaN
# 34821             NaN
# 34822             NaN
#
# [34823 rows x 21 columns]

# %%
almost_done['mh_treatment'] = pd.notna(almost_done["refferal_source"])

# %%
almost_done.shape
# Out:
# (34823, 22)

# %%
almost_done = almost_done.drop_duplicates()

# %%
almost_done = almost_done.dropna(subset = ['dedupe_id'])

# %%
almost_done.shape
# Out:
# (29504, 22)

# %%
almost_done.columns
# Out:
# Index(['mni_no', 'dedupe_id', 'dob', 'sex', 'race', 'mar_stat', 'city',
#        'state', 'zip', 'case_no', 'case_type', 'booking_no',
#        'arresting_agency', 'arresting_agency_type', 'booking_date',
#        'release_date', 'bail_type', 'bail_amt', 'bailed_out', 'pri_dx_value',
#        'refferal_source', 'mh_treatment'],
#       dtype='object')

# %%
def convert_datetime(df, cols):
    for col in cols:
        df[col] = pd.to_datetime(df[col])

# %%
convert_datetime(almost_done, ['booking_date', 'release_date', 'dob'])

# %%
#3 Pre-Process & Filling Missing Data#3 Pre-P 
def Detect_missing_value(df):
    '''
    Find out the columns have missing values

    Input:
        df: (pandas dataframe)
 
    Returns:
        a list of those column names
    '''
    rv = []
    for col in df.columns:
        if df[col].count() < df.shape[0]:
            rv.append(col)
            print(col, "has missing values.")
    return rv

# %%
Detect_missing_value(almost_done)
# Out:
# sex has missing values.
# mar_stat has missing values.
# city has missing values.
# state has missing values.
# zip has missing values.
# arresting_agency has missing values.
# arresting_agency_type has missing values.
# release_date has missing values.
# bail_type has missing values.
# bail_amt has missing values.
# pri_dx_value has missing values.
# refferal_source has missing values.
# ['sex',
#  'mar_stat',
#  'city',
#  'state',
#  'zip',
#  'arresting_agency',
#  'arresting_agency_type',
#  'release_date',
#  'bail_type',
#  'bail_amt',
#  'pri_dx_value',
#  'refferal_source']

# %%
# get numeric columns 
num_cols = almost_done._get_numeric_data().columns
num_cols
# Out:
# Index(['mni_no', 'dedupe_id', 'booking_no', 'bail_amt', 'bailed_out',
#        'mh_treatment'],
#       dtype='object')

# %%
#and then find out categorical columns
cate_cols = list(set(almost_done.columns) - set(num_cols))
cate_cols
# Out:
# ['mar_stat',
#  'race',
#  'case_type',
#  'bail_type',
#  'case_no',
#  'city',
#  'dob',
#  'arresting_agency_type',
#  'arresting_agency',
#  'refferal_source',
#  'sex',
#  'pri_dx_value',
#  'release_date',
#  'state',
#  'booking_date',
#  'zip']

# %%
# FILL IN MISSING VALUES WITH SELECTED METHODS FOR EACH TYPE 
def Fill_in(df, cols, method="mean"):
    '''
    Filling in missing values with "mean" or "median"
    
    Inputs:
        df: (pandas dataframe)
        a list of those column names
        method (string): mean or median
 
    Returns:
        pandas dataframe
    '''
    for col in cols:
        if df[col].dtype == 'object':
            try:
                df[col].fillna(df[col].mode()[0], inplace=True)
            except:
                df[col].fillna("")
        if method =='mean':
            val = df[col].mean()
        elif method =='median':
            val = df[col].median()
        elif method =='mode':
            val = df[col].mode()
            val = str(val)
        elif method == 'missing':
            val = "missing"
        df[col] = df[col].fillna(val)
        print ('Filling missing value for {} using {}'.format(col, method))
    return df

# %%
almost_done = Fill_in(almost_done, ['city', 'state', 'race', 'mar_stat'], "missing")
# Out:
# Filling missing value for city using missing
# Filling missing value for state using missing
# Filling missing value for race using missing
# Filling missing value for mar_stat using missing

# %%
fill_with_mode = ['sex', 'arresting_agency', 'arresting_agency_type', 'bail_type', 'pri_dx_value']

# %%
almost_done.sex.unique()
# Out:
# array(['MALE', 'FEMALE', nan], dtype=object)

# %%
almost_done = Fill_in(almost_done, fill_with_mode, "mode")
almost_done = Fill_in(almost_done, ['bail_amt'], "median")
# Out:
# Filling missing value for sex using mode
# Filling missing value for arresting_agency using mode
# Filling missing value for arresting_agency_type using mode
# Filling missing value for bail_type using mode
# Filling missing value for pri_dx_value using mode
# Filling missing value for bail_amt using median

# %%
Detect_missing_value(almost_done)
# Out:
# zip has missing values.
# release_date has missing values.
# refferal_source has missing values.
# ['zip', 'release_date', 'refferal_source']

# %%
almost_done['bailed_out'].head()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 5    True
# Name: bailed_out, dtype: bool

# %%
#convert dummy var
almost_done['bailed_out'] = almost_done['bailed_out']*1

# %%
#convert dummy var
almost_done['mh_treatment'] = almost_done['mh_treatment']*1

# %%
almost_done[almost_done['dedupe_id']==296410]
# Out:
#    mni_no  dedupe_id        dob   sex   race mar_stat    city state    zip  \
# 1  431835   296410.0 1971-01-01  MALE  WHITE        S  OLATHE    KS  66062
# 2  431835   296410.0 1971-01-01  MALE  WHITE        S  OLATHE    KS  66062
#
#      case_no     ...                          arresting_agency  \
# 1  13CR00129     ...       JOHNSON COUNTY SHERIFF'S DEPARTMENT
# 2  14CR00932     ...       JOHNSON COUNTY SHERIFF'S DEPARTMENT
#
#    arresting_agency_type booking_date release_date bail_type bail_amt  \
# 1         COUNTY SHERIFF   2013-01-19   2013-01-22       SUR  10000.0
# 2         COUNTY SHERIFF   2014-05-02   2014-05-02       SUR   5000.0
#
#   bailed_out   pri_dx_value  refferal_source mh_treatment
# 1          1  SOCIAL PHOBIA           OTHERS            1
# 2          1  SOCIAL PHOBIA           OTHERS            1
#
# [2 rows x 22 columns]

# %%
almost_done['re_entry'] = almost_done['dedupe_id'].map(almost_done['dedupe_id'].value_counts())

# %%
almost_done['re_entry'] = np.where(almost_done['re_entry']>1, 1, 0)

# %%
#create age at the released_date
almost_done['age']= almost_done['release_date'].dt.year - almost_done['dob'].dt.year

# %%
almost_done.head()
# Out:
#    mni_no  dedupe_id        dob     sex   race mar_stat      city state  \
# 0  679537   301831.0 1974-04-02    MALE  WHITE        M   SHAWNEE    KS
# 1  431835   296410.0 1971-01-01    MALE  WHITE        S    OLATHE    KS
# 2  431835   296410.0 1971-01-01    MALE  WHITE        S    OLATHE    KS
# 3  658145   350849.0 1997-04-12  FEMALE  WHITE        S  EDGERTON    KS
# 5  655865   370683.0 1984-08-03    MALE  WHITE        S    OLATHE    KS
#
#      zip    case_no  ...  booking_date  release_date bail_type bail_amt  \
# 0  66226  15CR00773  ...    2015-04-01    2015-04-01        CA  10000.0
# 1  66062  13CR00129  ...    2013-01-19    2013-01-22       SUR  10000.0
# 2  66062  14CR00932  ...    2014-05-02    2014-05-02       SUR   5000.0
# 3  66021  15CR02335  ...    2015-10-07    2015-10-07       SUR  10000.0
# 5  66062  13CR00468  ...    2013-03-03    2013-03-03       SUR   1000.0
#
#   bailed_out                                       pri_dx_value  \
# 0          1  MAJOR DEPRESSIVE DISORDER, SINGLE EPISODE, MOD...
# 1          1                                      SOCIAL PHOBIA
# 2          1                                      SOCIAL PHOBIA
# 3          1                    UNSPECIFIED AFFECTIVE PSYCHOSIS
# 5          1                    UNSPECIFIED AFFECTIVE PSYCHOSIS
#
#   refferal_source  mh_treatment  re_entry   age
# 0          OTHERS             1         0  41.0
# 1          OTHERS             1         1  42.0
# 2          OTHERS             1         1  43.0
# 3             NaN             0         0  18.0
# 5             NaN             0         0  29.0
#
# [5 rows x 24 columns]

# %%
almost_done.to_csv('clean_total.csv', index=False)

# %%
def within_frame(df, id_num='dedupe_id', timestamp='booking_date', col_name='re-entry', duration=365):
    df = df.sort_values(by=[id_num, timestamp])
    df['{}'.format(col_name)] = df.groupby(id_num)[timestamp].diff()
    df['{}'.format(col_name)] = df['{}'.format(col_name)].apply(lambda x: x.days)
    df['within_{}'.format(duration)] = np.where(df['{}'.format(col_name)]>duration, 1, 0)    

    return df

# %%
##################up to now
