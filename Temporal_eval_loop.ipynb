# %%
import pandas as pd
import numpy as np

# %%
total = pd.merge(df, acs, on='zip', how='inner')

# %%
total.shape
# Out:
# (24433, 43)

# %%
df = total.copy()

# %%
cd ../code
# Out:
# /Users/jeeyoon_song/Desktop/syntaxerror-mlpp2018/code

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import graphviz
import seaborn as sns; sns.set()
from sklearn.linear_model import SGDClassifier 
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, AdaBoostClassifier, ExtraTreesClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB
from sklearn.neighbors.nearest_centroid import NearestCentroid
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split, ParameterGrid
from sklearn.metrics import *
import time


# %matplotlib inline

import final_connection
import final_default_grids
import final_explore_and_viz
import final_load_dfs
import final_plot
import final_preprocessing
import final_temporal
import indpv_lists as final_options
import jocojims
import final_classifier_final
import final_pipeline
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
DROP = (jocojims.DROP_COLS)

# %%
DROP.remove('release_date')
DROP.remove('dedupe_id')
print(DROP)
# Out:
# ['re_entry', 'mni_no', 'dob', 'state', 'city', 'zip', 'case_no', 'booking_no', 'after_released']

# %%
# DROPPING COLUMNS NOT USED IN ANALYSIS
print('DROPPING THESE COLUMNS: ', DROP)
df = df.drop(DROP, axis = 1)
print (' ')

# CREATING DUMMIES
print ('The following columns have been broken into dummies:' , jocojims.DUMMIES)
for dummy in jocojims.DUMMIES:
    df = final_preprocessing.dummy_variable(dummy, df)
print (' ')

# DISCRETIZATION
for category in jocojims.CATS:
    df = final_preprocessing.bin_gen(df, category, '_bin', 'suffix' )
print ('Discretizing the following variables: ', jocojims.CATS)
print (' ')
# Out:
# DROPPING THESE COLUMNS:  ['re_entry', 'mni_no', 'dob', 'state', 'city', 'zip', 'case_no', 'booking_no', 'after_released']
#
# The following columns have been broken into dummies: ['sex', 'race', 'mar_stat', 'case_type', 'arresting_agency', 'arresting_agency_type', 'bail_type', 'pri_dx_value', 'refferal_source']
#
# Discretizing the following variables:  ['age', 'per_capita_income', 'poverty_stat', 'household_income', 'mortgage_stat', 'school_enrollment_16-19', 'own_children_under18', 'SSI_income', 'grandparent_care', 'military_service', 'education_25', 'property_value_occupied', 'retirement_income', 'rent_over_income', 'bail_amt']

# %%
from IPython.display import display

# %%
result = final_pipeline.temporal_eval(final_options.all_var, df)
# Out:
# Train_Start: 2015-04-29  Train_End: 2015-10-29
# Test_Start: 2015-10-30  Test_End: 2016-04-30
# /Users/jeeyoon_song/Desktop/syntaxerror-mlpp2018/code/final_pipeline.py:525: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df[col1] = pd.to_datetime(df[col1])
# /Users/jeeyoon_song/Desktop/syntaxerror-mlpp2018/code/final_pipeline.py:526: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df[col2] = pd.to_datetime(df[col2])
# /Users/jeeyoon_song/Desktop/syntaxerror-mlpp2018/code/final_pipeline.py:528: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['after_prev_booked'] = df.groupby(id)[col1].diff()
# /Users/jeeyoon_song/Desktop/syntaxerror-mlpp2018/code/final_pipeline.py:529: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['stayed'] = df[col2] - df[col1]
# /Users/jeeyoon_song/Desktop/syntaxerror-mlpp2018/code/final_pipeline.py:530: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['stayed'] = df['stayed'].shift(1)
# /Users/jeeyoon_song/Desktop/syntaxerror-mlpp2018/code/final_pipeline.py:534: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['after_released'] = df['after_prev_booked'] - df['stayed']
# /Users/jeeyoon_song/Desktop/syntaxerror-mlpp2018/code/final_pipeline.py:536: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['after_released'] = df['after_released'].astype('timedelta64[D]')
# /Users/jeeyoon_song/Desktop/syntaxerror-mlpp2018/code/final_pipeline.py:542: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df[time_frame] = np.where(df['after_released'] <= within, 1, 0)
# RF
# {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# {'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# {'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# {'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# {'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# {'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# {'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# {'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# {'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# {'max_depth': 50, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# {'max_depth': 50, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# {'max_depth': 50, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# {'max_depth': 50, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# DT
# {'criterion': 'gini', 'max_depth': 1, 'min_samples_split': 2}
# {'criterion': 'gini', 'max_depth': 1, 'min_samples_split': 5}
# {'criterion': 'gini', 'max_depth': 1, 'min_samples_split': 10}
# {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 2}
# {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 5}
# {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 10}
# {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2}
# {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 5}
# {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 10}
# {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2}
# {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 5}
# {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10}
# {'criterion': 'gini', 'max_depth': 50, 'min_samples_split': 2}
# {'criterion': 'gini', 'max_depth': 50, 'min_samples_split': 5}
# {'criterion': 'gini', 'max_depth': 50, 'min_samples_split': 10}
# {'criterion': 'gini', 'max_depth': 100, 'min_samples_split': 2}
# {'criterion': 'gini', 'max_depth': 100, 'min_samples_split': 5}
# {'criterion': 'gini', 'max_depth': 100, 'min_samples_split': 10}
# {'criterion': 'entropy', 'max_depth': 1, 'min_samples_split': 2}
# {'criterion': 'entropy', 'max_depth': 1, 'min_samples_split': 5}
# {'criterion': 'entropy', 'max_depth': 1, 'min_samples_split': 10}
# {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 2}
# {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 5}
# {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 10}
# {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 2}
# {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 5}
# {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 10}
# {'criterion': 'entropy', 'max_depth': 20, 'min_samples_split': 2}
# {'criterion': 'entropy', 'max_depth': 20, 'min_samples_split': 5}
# {'criterion': 'entropy', 'max_depth': 20, 'min_samples_split': 10}
# {'criterion': 'entropy', 'max_depth': 50, 'min_samples_split': 2}
# {'criterion': 'entropy', 'max_depth': 50, 'min_samples_split': 5}
# {'criterion': 'entropy', 'max_depth': 50, 'min_samples_split': 10}
# {'criterion': 'entropy', 'max_depth': 100, 'min_samples_split': 2}
# {'criterion': 'entropy', 'max_depth': 100, 'min_samples_split': 5}
# {'criterion': 'entropy', 'max_depth': 100, 'min_samples_split': 10}
# KNN
# {'algorithm': 'auto', 'n_neighbors': 1, 'weights': 'uniform'}
# {'algorithm': 'auto', 'n_neighbors': 1, 'weights': 'distance'}
# {'algorithm': 'auto', 'n_neighbors': 5, 'weights': 'uniform'}
# {'algorithm': 'auto', 'n_neighbors': 5, 'weights': 'distance'}
# {'algorithm': 'auto', 'n_neighbors': 10, 'weights': 'uniform'}
# {'algorithm': 'auto', 'n_neighbors': 10, 'weights': 'distance'}
# {'algorithm': 'auto', 'n_neighbors': 25, 'weights': 'uniform'}
# {'algorithm': 'auto', 'n_neighbors': 25, 'weights': 'distance'}
# {'algorithm': 'auto', 'n_neighbors': 50, 'weights': 'uniform'}
# {'algorithm': 'auto', 'n_neighbors': 50, 'weights': 'distance'}
# {'algorithm': 'auto', 'n_neighbors': 100, 'weights': 'uniform'}
# {'algorithm': 'auto', 'n_neighbors': 100, 'weights': 'distance'}
# {'algorithm': 'ball_tree', 'n_neighbors': 1, 'weights': 'uniform'}
# {'algorithm': 'ball_tree', 'n_neighbors': 1, 'weights': 'distance'}
# {'algorithm': 'ball_tree', 'n_neighbors': 5, 'weights': 'uniform'}
# {'algorithm': 'ball_tree', 'n_neighbors': 5, 'weights': 'distance'}
# {'algorithm': 'ball_tree', 'n_neighbors': 10, 'weights': 'uniform'}
# {'algorithm': 'ball_tree', 'n_neighbors': 10, 'weights': 'distance'}
# {'algorithm': 'ball_tree', 'n_neighbors': 25, 'weights': 'uniform'}
# {'algorithm': 'ball_tree', 'n_neighbors': 25, 'weights': 'distance'}
# {'algorithm': 'ball_tree', 'n_neighbors': 50, 'weights': 'uniform'}
# {'algorithm': 'ball_tree', 'n_neighbors': 50, 'weights': 'distance'}
# {'algorithm': 'ball_tree', 'n_neighbors': 100, 'weights': 'uniform'}
# {'algorithm': 'ball_tree', 'n_neighbors': 100, 'weights': 'distance'}
# {'algorithm': 'kd_tree', 'n_neighbors': 1, 'weights': 'uniform'}
# {'algorithm': 'kd_tree', 'n_neighbors': 1, 'weights': 'distance'}
# {'algorithm': 'kd_tree', 'n_neighbors': 5, 'weights': 'uniform'}
# {'algorithm': 'kd_tree', 'n_neighbors': 5, 'weights': 'distance'}
# {'algorithm': 'kd_tree', 'n_neighbors': 10, 'weights': 'uniform'}
# {'algorithm': 'kd_tree', 'n_neighbors': 10, 'weights': 'distance'}
# {'algorithm': 'kd_tree', 'n_neighbors': 25, 'weights': 'uniform'}
# {'algorithm': 'kd_tree', 'n_neighbors': 25, 'weights': 'distance'}
# {'algorithm': 'kd_tree', 'n_neighbors': 50, 'weights': 'uniform'}
# {'algorithm': 'kd_tree', 'n_neighbors': 50, 'weights': 'distance'}
# {'algorithm': 'kd_tree', 'n_neighbors': 100, 'weights': 'uniform'}
# {'algorithm': 'kd_tree', 'n_neighbors': 100, 'weights': 'distance'}
# NB
# {}
# ET
# {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'gini', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'gini', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'gini', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'gini', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'gini', 'max_depth': 50, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'gini', 'max_depth': 50, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'gini', 'max_depth': 50, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'gini', 'max_depth': 50, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 50, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 50, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 50, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 50, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
#     model_type                                                clf  \
# 42          DT  DecisionTreeClassifier(class_weight=None, crit...
# 109         ET  (ExtraTreeClassifier(class_weight=None, criter...
# 63         KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 88          NB                            GaussianNB(priors=None)
# 2           RF  (DecisionTreeClassifier(class_weight=None, cri...
#
#                                             parameters   auc-roc  precision_5  \
# 42   {'criterion': 'entropy', 'max_depth': 10, 'min...  0.932505          1.0
# 109  {'criterion': 'entropy', 'max_depth': 5, 'max_...  0.874948          1.0
# 63   {'algorithm': 'auto', 'n_neighbors': 100, 'wei...  0.744513          1.0
# 88                                                  {}  0.500000          1.0
# 2    {'max_depth': 5, 'max_features': 'sqrt', 'min_...  0.785093          1.0
#
#      accuracy_5  recall_5      f1_5
# 42     0.198529  0.052174  0.099174
# 109    0.198529  0.052174  0.099174
# 63     0.198529  0.052174  0.099174
# 88     0.198529  0.052174  0.099174
# 2      0.198529  0.052174  0.099174
# Feature ranking for within_1yrs
# 1. bailed_out (0.122466)
# 2. bail_amt_bin4 (0.095254)
# 3. age_bin1 (0.079045)
# 4. school_enrollment_16-19_bin2 (0.052022)
# 5. retirement_income_bin1 (0.048703)
# 6. arresting_agency_typeCITY (0.042868)
# 7. arresting_agencyJOHNSON COUNTY SHERIFF'S DEPARTMENT (0.041050)
# 8. grandparent_care_bin1 (0.039343)
# 9. SSI_income_bin2 (0.037130)
# 10. pri_dx_valueUNSPECIFIED AFFECTIVE PSYCHOSIS (0.035654)
# Train_Start: 2014-10-29  Train_End: 2015-10-29
# Test_Start: 2015-10-30  Test_End: 2016-04-30
# /Users/jeeyoon_song/Desktop/syntaxerror-mlpp2018/code/final_pipeline.py:525: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df[col1] = pd.to_datetime(df[col1])
# /Users/jeeyoon_song/Desktop/syntaxerror-mlpp2018/code/final_pipeline.py:526: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df[col2] = pd.to_datetime(df[col2])
# /Users/jeeyoon_song/Desktop/syntaxerror-mlpp2018/code/final_pipeline.py:528: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['after_prev_booked'] = df.groupby(id)[col1].diff()
# /Users/jeeyoon_song/Desktop/syntaxerror-mlpp2018/code/final_pipeline.py:529: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['stayed'] = df[col2] - df[col1]
# /Users/jeeyoon_song/Desktop/syntaxerror-mlpp2018/code/final_pipeline.py:530: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['stayed'] = df['stayed'].shift(1)
# /Users/jeeyoon_song/Desktop/syntaxerror-mlpp2018/code/final_pipeline.py:534: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['after_released'] = df['after_prev_booked'] - df['stayed']
# /Users/jeeyoon_song/Desktop/syntaxerror-mlpp2018/code/final_pipeline.py:536: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['after_released'] = df['after_released'].astype('timedelta64[D]')
# /Users/jeeyoon_song/Desktop/syntaxerror-mlpp2018/code/final_pipeline.py:542: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df[time_frame] = np.where(df['after_released'] <= within, 1, 0)
# RF
# {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# {'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# {'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# {'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# {'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# {'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# {'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# {'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# {'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# {'max_depth': 50, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# {'max_depth': 50, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# {'max_depth': 50, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# {'max_depth': 50, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# DT
# {'criterion': 'gini', 'max_depth': 1, 'min_samples_split': 2}
# {'criterion': 'gini', 'max_depth': 1, 'min_samples_split': 5}
# {'criterion': 'gini', 'max_depth': 1, 'min_samples_split': 10}
# {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 2}
# {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 5}
# {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 10}
# {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2}
# {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 5}
# {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 10}
# {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2}
# {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 5}
# {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10}
# {'criterion': 'gini', 'max_depth': 50, 'min_samples_split': 2}
# {'criterion': 'gini', 'max_depth': 50, 'min_samples_split': 5}
# {'criterion': 'gini', 'max_depth': 50, 'min_samples_split': 10}
# {'criterion': 'gini', 'max_depth': 100, 'min_samples_split': 2}
# {'criterion': 'gini', 'max_depth': 100, 'min_samples_split': 5}
# {'criterion': 'gini', 'max_depth': 100, 'min_samples_split': 10}
# {'criterion': 'entropy', 'max_depth': 1, 'min_samples_split': 2}
# {'criterion': 'entropy', 'max_depth': 1, 'min_samples_split': 5}
# {'criterion': 'entropy', 'max_depth': 1, 'min_samples_split': 10}
# {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 2}
# {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 5}
# {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 10}
# {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 2}
# {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 5}
# {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 10}
# {'criterion': 'entropy', 'max_depth': 20, 'min_samples_split': 2}
# {'criterion': 'entropy', 'max_depth': 20, 'min_samples_split': 5}
# {'criterion': 'entropy', 'max_depth': 20, 'min_samples_split': 10}
# {'criterion': 'entropy', 'max_depth': 50, 'min_samples_split': 2}
# {'criterion': 'entropy', 'max_depth': 50, 'min_samples_split': 5}
# {'criterion': 'entropy', 'max_depth': 50, 'min_samples_split': 10}
# {'criterion': 'entropy', 'max_depth': 100, 'min_samples_split': 2}
# {'criterion': 'entropy', 'max_depth': 100, 'min_samples_split': 5}
# {'criterion': 'entropy', 'max_depth': 100, 'min_samples_split': 10}
# KNN
# {'algorithm': 'auto', 'n_neighbors': 1, 'weights': 'uniform'}
# {'algorithm': 'auto', 'n_neighbors': 1, 'weights': 'distance'}
# {'algorithm': 'auto', 'n_neighbors': 5, 'weights': 'uniform'}
# {'algorithm': 'auto', 'n_neighbors': 5, 'weights': 'distance'}
# {'algorithm': 'auto', 'n_neighbors': 10, 'weights': 'uniform'}
# {'algorithm': 'auto', 'n_neighbors': 10, 'weights': 'distance'}
# {'algorithm': 'auto', 'n_neighbors': 25, 'weights': 'uniform'}
# {'algorithm': 'auto', 'n_neighbors': 25, 'weights': 'distance'}
# {'algorithm': 'auto', 'n_neighbors': 50, 'weights': 'uniform'}
# {'algorithm': 'auto', 'n_neighbors': 50, 'weights': 'distance'}
# {'algorithm': 'auto', 'n_neighbors': 100, 'weights': 'uniform'}
# {'algorithm': 'auto', 'n_neighbors': 100, 'weights': 'distance'}
# {'algorithm': 'ball_tree', 'n_neighbors': 1, 'weights': 'uniform'}
# {'algorithm': 'ball_tree', 'n_neighbors': 1, 'weights': 'distance'}
# {'algorithm': 'ball_tree', 'n_neighbors': 5, 'weights': 'uniform'}
# {'algorithm': 'ball_tree', 'n_neighbors': 5, 'weights': 'distance'}
# {'algorithm': 'ball_tree', 'n_neighbors': 10, 'weights': 'uniform'}
# {'algorithm': 'ball_tree', 'n_neighbors': 10, 'weights': 'distance'}
# {'algorithm': 'ball_tree', 'n_neighbors': 25, 'weights': 'uniform'}
# {'algorithm': 'ball_tree', 'n_neighbors': 25, 'weights': 'distance'}
# {'algorithm': 'ball_tree', 'n_neighbors': 50, 'weights': 'uniform'}
# {'algorithm': 'ball_tree', 'n_neighbors': 50, 'weights': 'distance'}
# {'algorithm': 'ball_tree', 'n_neighbors': 100, 'weights': 'uniform'}
# {'algorithm': 'ball_tree', 'n_neighbors': 100, 'weights': 'distance'}
# {'algorithm': 'kd_tree', 'n_neighbors': 1, 'weights': 'uniform'}
# {'algorithm': 'kd_tree', 'n_neighbors': 1, 'weights': 'distance'}
# {'algorithm': 'kd_tree', 'n_neighbors': 5, 'weights': 'uniform'}
# {'algorithm': 'kd_tree', 'n_neighbors': 5, 'weights': 'distance'}
# {'algorithm': 'kd_tree', 'n_neighbors': 10, 'weights': 'uniform'}
# {'algorithm': 'kd_tree', 'n_neighbors': 10, 'weights': 'distance'}
# {'algorithm': 'kd_tree', 'n_neighbors': 25, 'weights': 'uniform'}
# {'algorithm': 'kd_tree', 'n_neighbors': 25, 'weights': 'distance'}
# {'algorithm': 'kd_tree', 'n_neighbors': 50, 'weights': 'uniform'}
# {'algorithm': 'kd_tree', 'n_neighbors': 50, 'weights': 'distance'}
# {'algorithm': 'kd_tree', 'n_neighbors': 100, 'weights': 'uniform'}
# {'algorithm': 'kd_tree', 'n_neighbors': 100, 'weights': 'distance'}
# NB
# {}
# ET
# {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'gini', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'gini', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'gini', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'gini', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'gini', 'max_depth': 50, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'gini', 'max_depth': 50, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'gini', 'max_depth': 50, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'gini', 'max_depth': 50, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 50, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 50, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 50, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 50, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
#    model_type                                                clf  \
# 37         DT  DecisionTreeClassifier(class_weight=None, crit...
# 91         ET  (ExtraTreeClassifier(class_weight=None, criter...
# 63        KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 88         NB                            GaussianNB(priors=None)
# 6          RF  (DecisionTreeClassifier(class_weight=None, cri...
#
#                                            parameters   auc-roc  precision_5  \
# 37  {'criterion': 'entropy', 'max_depth': 5, 'min_...  0.969772          1.0
# 91  {'criterion': 'gini', 'max_depth': 5, 'max_fea...  0.729400          1.0
# 63  {'algorithm': 'auto', 'n_neighbors': 100, 'wei...  0.639337          1.0
# 88                                                 {}  0.382609          1.0
# 6   {'max_depth': 5, 'max_features': 'log2', 'min_...  0.685093          1.0
#
#     accuracy_5  recall_5      f1_5
# 37    0.198529  0.052174  0.099174
# 91    0.198529  0.052174  0.099174
# 63    0.198529  0.052174  0.099174
# 88    0.198529  0.052174  0.099174
# 6     0.198529  0.052174  0.099174
# Feature ranking for within_1yrs
# 1. bailed_out (0.105310)
# 2. pri_dx_valueCONDUCT DISORDER, UNSPECIFIED ONSET (0.082477)
# 3. arresting_agencyMERRIAM P.D. (0.076151)
# 4. pri_dx_valueUNSPECIFIED HYPERKINETIC SYNDROME (0.069487)
# 5. pri_dx_valueBIPOLAR DISORDER, MANIC IN PARTIAL REMISSION (0.044722)
# 6. pri_dx_valueMAJOR DEPRESSIVE DISORDER, RECURRENT, SEVERE W/O PSYCH (0.043121)
# 7. case_typeDV (0.040927)
# 8. pri_dx_valuePROLONGED POST TRAUMATIC STRESS DISORDER (0.034359)
# 9. education_25_bin2 (0.032245)
# 10. pri_dx_valueBIPOLAR DISORDER, DEPRESSED, MODERATE (0.027222)
# Train_Start: 2014-04-29  Train_End: 2015-10-29
# Test_Start: 2015-10-30  Test_End: 2016-04-30
# /Users/jeeyoon_song/Desktop/syntaxerror-mlpp2018/code/final_pipeline.py:525: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df[col1] = pd.to_datetime(df[col1])
# /Users/jeeyoon_song/Desktop/syntaxerror-mlpp2018/code/final_pipeline.py:526: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df[col2] = pd.to_datetime(df[col2])
# /Users/jeeyoon_song/Desktop/syntaxerror-mlpp2018/code/final_pipeline.py:528: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['after_prev_booked'] = df.groupby(id)[col1].diff()
# /Users/jeeyoon_song/Desktop/syntaxerror-mlpp2018/code/final_pipeline.py:529: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['stayed'] = df[col2] - df[col1]
# /Users/jeeyoon_song/Desktop/syntaxerror-mlpp2018/code/final_pipeline.py:530: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['stayed'] = df['stayed'].shift(1)
# /Users/jeeyoon_song/Desktop/syntaxerror-mlpp2018/code/final_pipeline.py:534: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['after_released'] = df['after_prev_booked'] - df['stayed']
# /Users/jeeyoon_song/Desktop/syntaxerror-mlpp2018/code/final_pipeline.py:536: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['after_released'] = df['after_released'].astype('timedelta64[D]')
# /Users/jeeyoon_song/Desktop/syntaxerror-mlpp2018/code/final_pipeline.py:542: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df[time_frame] = np.where(df['after_released'] <= within, 1, 0)
# RF
# {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# {'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# {'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# {'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# {'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# {'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# {'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# {'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# {'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# {'max_depth': 50, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# {'max_depth': 50, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# {'max_depth': 50, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# {'max_depth': 50, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# DT
# {'criterion': 'gini', 'max_depth': 1, 'min_samples_split': 2}
# {'criterion': 'gini', 'max_depth': 1, 'min_samples_split': 5}
# {'criterion': 'gini', 'max_depth': 1, 'min_samples_split': 10}
# {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 2}
# {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 5}
# {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 10}
# {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2}
# {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 5}
# {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 10}
# {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2}
# {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 5}
# {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10}
# {'criterion': 'gini', 'max_depth': 50, 'min_samples_split': 2}
# {'criterion': 'gini', 'max_depth': 50, 'min_samples_split': 5}
# {'criterion': 'gini', 'max_depth': 50, 'min_samples_split': 10}
# {'criterion': 'gini', 'max_depth': 100, 'min_samples_split': 2}
# {'criterion': 'gini', 'max_depth': 100, 'min_samples_split': 5}
# {'criterion': 'gini', 'max_depth': 100, 'min_samples_split': 10}
# {'criterion': 'entropy', 'max_depth': 1, 'min_samples_split': 2}
# {'criterion': 'entropy', 'max_depth': 1, 'min_samples_split': 5}
# {'criterion': 'entropy', 'max_depth': 1, 'min_samples_split': 10}
# {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 2}
# {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 5}
# {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 10}
# {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 2}
# {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 5}
# {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 10}
# {'criterion': 'entropy', 'max_depth': 20, 'min_samples_split': 2}
# {'criterion': 'entropy', 'max_depth': 20, 'min_samples_split': 5}
# {'criterion': 'entropy', 'max_depth': 20, 'min_samples_split': 10}
# {'criterion': 'entropy', 'max_depth': 50, 'min_samples_split': 2}
# {'criterion': 'entropy', 'max_depth': 50, 'min_samples_split': 5}
# {'criterion': 'entropy', 'max_depth': 50, 'min_samples_split': 10}
# {'criterion': 'entropy', 'max_depth': 100, 'min_samples_split': 2}
# {'criterion': 'entropy', 'max_depth': 100, 'min_samples_split': 5}
# {'criterion': 'entropy', 'max_depth': 100, 'min_samples_split': 10}
# KNN
# {'algorithm': 'auto', 'n_neighbors': 1, 'weights': 'uniform'}
# {'algorithm': 'auto', 'n_neighbors': 1, 'weights': 'distance'}
# {'algorithm': 'auto', 'n_neighbors': 5, 'weights': 'uniform'}
# {'algorithm': 'auto', 'n_neighbors': 5, 'weights': 'distance'}
# {'algorithm': 'auto', 'n_neighbors': 10, 'weights': 'uniform'}
# {'algorithm': 'auto', 'n_neighbors': 10, 'weights': 'distance'}
# {'algorithm': 'auto', 'n_neighbors': 25, 'weights': 'uniform'}
# {'algorithm': 'auto', 'n_neighbors': 25, 'weights': 'distance'}
# {'algorithm': 'auto', 'n_neighbors': 50, 'weights': 'uniform'}
# {'algorithm': 'auto', 'n_neighbors': 50, 'weights': 'distance'}
# {'algorithm': 'auto', 'n_neighbors': 100, 'weights': 'uniform'}
# {'algorithm': 'auto', 'n_neighbors': 100, 'weights': 'distance'}
# {'algorithm': 'ball_tree', 'n_neighbors': 1, 'weights': 'uniform'}
# {'algorithm': 'ball_tree', 'n_neighbors': 1, 'weights': 'distance'}
# {'algorithm': 'ball_tree', 'n_neighbors': 5, 'weights': 'uniform'}
# {'algorithm': 'ball_tree', 'n_neighbors': 5, 'weights': 'distance'}
# {'algorithm': 'ball_tree', 'n_neighbors': 10, 'weights': 'uniform'}
# {'algorithm': 'ball_tree', 'n_neighbors': 10, 'weights': 'distance'}
# {'algorithm': 'ball_tree', 'n_neighbors': 25, 'weights': 'uniform'}
# {'algorithm': 'ball_tree', 'n_neighbors': 25, 'weights': 'distance'}
# {'algorithm': 'ball_tree', 'n_neighbors': 50, 'weights': 'uniform'}
# {'algorithm': 'ball_tree', 'n_neighbors': 50, 'weights': 'distance'}
# {'algorithm': 'ball_tree', 'n_neighbors': 100, 'weights': 'uniform'}
# {'algorithm': 'ball_tree', 'n_neighbors': 100, 'weights': 'distance'}
# {'algorithm': 'kd_tree', 'n_neighbors': 1, 'weights': 'uniform'}
# {'algorithm': 'kd_tree', 'n_neighbors': 1, 'weights': 'distance'}
# {'algorithm': 'kd_tree', 'n_neighbors': 5, 'weights': 'uniform'}
# {'algorithm': 'kd_tree', 'n_neighbors': 5, 'weights': 'distance'}
# {'algorithm': 'kd_tree', 'n_neighbors': 10, 'weights': 'uniform'}
# {'algorithm': 'kd_tree', 'n_neighbors': 10, 'weights': 'distance'}
# {'algorithm': 'kd_tree', 'n_neighbors': 25, 'weights': 'uniform'}
# {'algorithm': 'kd_tree', 'n_neighbors': 25, 'weights': 'distance'}
# {'algorithm': 'kd_tree', 'n_neighbors': 50, 'weights': 'uniform'}
# {'algorithm': 'kd_tree', 'n_neighbors': 50, 'weights': 'distance'}
# {'algorithm': 'kd_tree', 'n_neighbors': 100, 'weights': 'uniform'}
# {'algorithm': 'kd_tree', 'n_neighbors': 100, 'weights': 'distance'}
# NB
# {}
# ET
# {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'gini', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'gini', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'gini', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'gini', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'gini', 'max_depth': 50, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'gini', 'max_depth': 50, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'gini', 'max_depth': 50, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'gini', 'max_depth': 50, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 50, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 50, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 50, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 50, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
#     model_type                                                clf  \
# 26          DT  DecisionTreeClassifier(class_weight=None, crit...
# 111         ET  (ExtraTreeClassifier(class_weight=None, criter...
# 63         KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 88          NB                            GaussianNB(priors=None)
# 2           RF  (DecisionTreeClassifier(class_weight=None, cri...
#
#                                             parameters   auc-roc  precision_5  \
# 26   {'criterion': 'gini', 'max_depth': 20, 'min_sa...  0.651967          1.0
# 111  {'criterion': 'entropy', 'max_depth': 5, 'max_...  0.702070          1.0
# 63   {'algorithm': 'auto', 'n_neighbors': 100, 'wei...  0.673706          1.0
# 88                                                  {}  0.334161          1.0
# 2    {'max_depth': 5, 'max_features': 'sqrt', 'min_...  0.674948          1.0
#
#      accuracy_5  recall_5      f1_5
# 26     0.198529  0.052174  0.099174
# 111    0.198529  0.052174  0.099174
# 63     0.198529  0.052174  0.099174
# 88     0.198529  0.052174  0.099174
# 2      0.198529  0.052174  0.099174
# Feature ranking for within_1yrs
# 1. age_bin1 (0.069911)
# 2. bail_typePR (0.052011)
# 3. military_service_bin4 (0.050027)
# 4. pri_dx_valueBIPOLAR DISORDER, MANIC IN PARTIAL REMISSION (0.046467)
# 5. own_children_under18_bin4 (0.035598)
# 6. education_25_bin1 (0.032771)
# 7. bail_typeSUR (0.031650)
# 8. sexMALE (0.026733)
# 9. pri_dx_valueUNSPECIFIED AFFECTIVE PSYCHOSIS (0.025830)
# 10. arresting_agencyMERRIAM P.D. (0.025258)
# Train_Start: 2013-10-29  Train_End: 2015-10-29
# Test_Start: 2015-10-30  Test_End: 2016-04-30
# /Users/jeeyoon_song/Desktop/syntaxerror-mlpp2018/code/final_pipeline.py:525: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df[col1] = pd.to_datetime(df[col1])
# /Users/jeeyoon_song/Desktop/syntaxerror-mlpp2018/code/final_pipeline.py:526: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df[col2] = pd.to_datetime(df[col2])
# /Users/jeeyoon_song/Desktop/syntaxerror-mlpp2018/code/final_pipeline.py:528: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['after_prev_booked'] = df.groupby(id)[col1].diff()
# /Users/jeeyoon_song/Desktop/syntaxerror-mlpp2018/code/final_pipeline.py:529: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['stayed'] = df[col2] - df[col1]
# /Users/jeeyoon_song/Desktop/syntaxerror-mlpp2018/code/final_pipeline.py:530: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['stayed'] = df['stayed'].shift(1)
# /Users/jeeyoon_song/Desktop/syntaxerror-mlpp2018/code/final_pipeline.py:534: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['after_released'] = df['after_prev_booked'] - df['stayed']
# /Users/jeeyoon_song/Desktop/syntaxerror-mlpp2018/code/final_pipeline.py:536: SettingWithCopyWarning:
# ...
# {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 50, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 50, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 50, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# {'criterion': 'entropy', 'max_depth': 50, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
#    model_type                                                clf  \
# 43         DT  DecisionTreeClassifier(class_weight=None, crit...
# 97         ET  (ExtraTreeClassifier(class_weight=None, criter...
# 69        KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 88         NB                            GaussianNB(priors=None)
# 12         RF  (DecisionTreeClassifier(class_weight=None, cri...
#
#                                            parameters   auc-roc  precision_5  \
# 43  {'criterion': 'entropy', 'max_depth': 20, 'min...  0.522774          1.0
# 97  {'criterion': 'gini', 'max_depth': 50, 'max_fe...  0.455280          1.0
# 69  {'algorithm': 'ball_tree', 'n_neighbors': 10, ...  0.423810          1.0
# 88                                                 {}  0.313251          1.0
# 12  {'max_depth': 50, 'max_features': 'log2', 'min...  0.427329          1.0
#
#     accuracy_5  recall_5      f1_5
# 43    0.198529  0.052174  0.099174
# 97    0.198529  0.052174  0.099174
# 69    0.198529  0.052174  0.099174
# 88    0.198529  0.052174  0.099174
# 12    0.198529  0.052174  0.099174
# Feature ranking for within_1yrs
# 1. bail_amt_bin3 (0.029892)
# 2. bailed_out (0.027326)
# 3. pri_dx_valueUNSPECIFIED AFFECTIVE PSYCHOSIS (0.023696)
# 4. age_bin2 (0.023547)
# 5. age_bin1 (0.023475)
# 6. bail_amt_bin4 (0.023184)
# 7. age_bin3 (0.022775)
# 8. refferal_sourceOTHERS (0.019940)
# 9. case_typeCR (0.019254)
# 10. age_bin4 (0.018385)
# Train_Start: 2014-04-29  Train_End: 2014-10-29
# Test_Start: 2014-10-30  Test_End: 2015-04-30
# /Users/jeeyoon_song/Desktop/syntaxerror-mlpp2018/code/final_pipeline.py:525: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df[col1] = pd.to_datetime(df[col1])
# /Users/jeeyoon_song/Desktop/syntaxerror-mlpp2018/code/final_pipeline.py:526: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df[col2] = pd.to_datetime(df[col2])
# /Users/jeeyoon_song/Desktop/syntaxerror-mlpp2018/code/final_pipeline.py:528: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['after_prev_booked'] = df.groupby(id)[col1].diff()
# /Users/jeeyoon_song/Desktop/syntaxerror-mlpp2018/code/final_pipeline.py:529: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['stayed'] = df[col2] - df[col1]
# /Users/jeeyoon_song/Desktop/syntaxerror-mlpp2018/code/final_pipeline.py:530: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['stayed'] = df['stayed'].shift(1)
# /Users/jeeyoon_song/Desktop/syntaxerror-mlpp2018/code/final_pipeline.py:534: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['after_released'] = df['after_prev_booked'] - df['stayed']
# /Users/jeeyoon_song/Desktop/syntaxerror-mlpp2018/code/final_pipeline.py:536: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['after_released'] = df['after_released'].astype('timedelta64[D]')
# /Users/jeeyoon_song/Desktop/syntaxerror-mlpp2018/code/final_pipeline.py:542: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df[time_frame] = np.where(df['after_released'] <= within, 1, 0)
# RF
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# DT
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# KNN
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# NB
# index 1 is out of bounds for axis 1 with size 1
# ET
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# index 1 is out of bounds for axis 1 with size 1
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'level_1'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-8b3cf0f4bebb> in <module>()
# ----> 1 result = final_pipeline.temporal_eval(final_options.all_var, df)
#
# /Users/jeeyoon_song/Desktop/syntaxerror-mlpp2018/code/final_pipeline.py in temporal_eval(features, df, col, target, save)
#     601                 result = classifiers_loop(x_train, x_test, y_train, y_test)
#     602                 result.to_csv('{} {} {} {}.csv'.format(train_start_time,train_end_time,test_start_time,test_end_time), mode='a', index=False)
# --> 603                 best = best_grid(result)
#     604                 feature_importance(x_train, y_train, best)
#     605                 #plot_mult(MODELS_TO_RUN, x_train, x_test, y_train, y_test, best)
#
# /Users/jeeyoon_song/Desktop/syntaxerror-mlpp2018/code/final_pipeline.py in best_grid(rdf, method)
#     424     model = model.to_frame()
#     425     model.reset_index(inplace = True)
# --> 426     rows = list(model['level_1'])
#     427     display(rdf.loc[rows].iloc[:,0:8])
#     428     for row in rows:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'level_1'
